# %% [markdown]
# ### Map Projection 2: MPJ261S

# %% [markdown]
# ##### ~ Major Assignment 2: *CRS's*

# %%
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mticker
import cartopy.crs as ccrs
#import cartopy.feature as cfeature
#from cartopy.feature import ShapelyFeature
#import cartopy.io.shapereader as shpreader
#from cartopy.io.shapereader import Reader
from cartopy.mpl.ticker import (LongitudeFormatter, LatitudeFormatter)

import pyproj

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=3, 
                                                  central_latitude=48))
plt.title('RGF93 / CC48', fontweight="bold", pad=20)
ax.stock_img()
ax.gridlines(draw_labels=True)

# epsg:3948 extents
#lat_corners = np.array([618180.541, 618180.54, 6527546.03, 6527546.03])
#lon_corners = np.array([2211981.05, 7620707.95, 7620707.95, 2211981.05]) 
lat_corners = np.array([41.15, 41.15, 41.15, 51.56, 51.56, 51.56])
lon_corners = np.array([-9.86, 0.0, 10.38, 10.38, 0.0, -9.86])

poly_corners = np.zeros((len(lat_corners), 2), np.float64)
poly_corners[:,0] = lon_corners
poly_corners[:,1] = lat_corners

poly = mpatches.Polygon(poly_corners, closed=True, #ec='r', 
                        fill=True, lw=1, fc="grey",
                        alpha=0.4, 
                        #transform=ccrs.epsg(3948))
                        transform=ccrs.Geodetic(),
                        label = 'Projected bounds')

# epsg:3948 center coordinates
plt.plot(1489088.51, 7020857.23, color='blue', marker='o',
         markersize=1, transform=ccrs.epsg(3948)) 
    
ax.add_patch(poly)

lat_corners2 = np.array([47.5, 47.5, 47.5, 48.5, 48.5,  48.5])
lon_corners2 = np.array([-9, 0.0, 10, 10, 0.0, -9]) 

poly_corners2 = np.zeros((len(lat_corners2), 2), np.float64)
poly_corners2[:,0] = lon_corners2
poly_corners2[:,1] = lat_corners2

poly2 = mpatches.Polygon(poly_corners2, closed=True, ec='r', 
                        fill=False, lw=1, #fc="grey",
                        alpha=1, 
                        #transform=ccrs.epsg(2048))
                        transform=ccrs.Geodetic(),
                        label = 'RGF93 / CC48 extent')
ax.add_patch(poly2)

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='grey', alpha=0.4, linestyle='--')
gl.xlabels = False
gl.ylabels = False
#gl.left_labels = True
#gl.ylines = True
gl.ylocator = mticker.FixedLocator([48])
gl.xlocator = mticker.FixedLocator([3])
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size': 15, 'color': 'black'}
gl.ylabel_style = {'color': 'grey', 'weight': 'bold'}

#add legend
ax.legend(bbox_to_anchor=(1.1, 1.1), loc='upper right')
#save
plt.savefig('./img/RGF93_CC48.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=21.0, 
                                                 central_latitude=-25.0))
plt.title('Haartebeeshoek94 / Lo21', fontweight="bold", pad=20)
ax.stock_img()
ax.gridlines()#draw_labels=True)

# epsg:2048 extents
#lat_corners = np.array([545943.69, 545943.69, 5604641.53, 5604641.53])
#lon_corners = np.array([-2294213.92, 2618727.19, 2618727.19, -2294213.92]) 
lat_corners = np.array([-50, -50, -50, -22, -22, -22])
lon_corners = np.array([13, 20, 42, 42, 20, 13]) 

poly_corners = np.zeros((len(lat_corners), 2), np.float64)
poly_corners[:,0] = lon_corners
poly_corners[:,1] = lat_corners

poly = mpatches.Polygon(poly_corners, closed=True, #ec='r', 
                        fill=True, lw=1, fc="grey",
                        alpha=0.4, 
                        #transform=ccrs.epsg(2048))
                        transform=ccrs.Geodetic(),
                        label = 'Projected bounds')
ax.add_patch(poly)

lat_corners2 = np.array([-50, -50, -22,  -22])
lon_corners2 = np.array([19, 23, 23,  19]) 

poly_corners2 = np.zeros((len(lat_corners2), 2), np.float64)
poly_corners2[:,0] = lon_corners2
poly_corners2[:,1] = lat_corners2

poly2 = mpatches.Polygon(poly_corners2, closed=True, ec='r', 
                        fill=False, lw=1, #fc="grey",
                        alpha=1, 
                        #transform=ccrs.epsg(2048))
                        transform=ccrs.Geodetic(),
                        label = 'Lo21 extent')
ax.add_patch(poly2)

# epsg:2048 center coordinates
plt.plot(-637932.55, 4033903.41, color='blue', marker='o',
         markersize=1, transform=ccrs.epsg(2048))

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='grey', alpha=0.5, linestyle='--')
gl.xlabels = True
gl.ylabels = True
#gl.left_labels = True
gl.ylines = False
#gl.ylocator = mticker.FixedLocator([])#[0, -15, -30, -80])
gl.xlocator = mticker.FixedLocator([21])
gl.xformatter = LongitudeFormatter()
#gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size': 15, 'color': 'black'}
gl.ylabel_style = {'color': 'grey', 'weight': 'bold'}

#add legend
ax.legend(bbox_to_anchor=(1.1, 1.05), loc='upper right')
#save
plt.savefig('./img/Haartebeeshoek94Lo21.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=75.0, 
                                                 central_latitude=43.0))
plt.title('WGS 84 / UTM zone 43N', fontweight="bold", pad=20)
ax.stock_img()
ax.gridlines(draw_labels=True)

# EPSG:32643 extents
#lat_corners = np.array([0.0, 0.0, 534994.66, 534994.66])
#lon_corners = np.array([166021.44, 9329005.18, 9329005.18, 166021.44]) 
lat_corners = np.array([0.0, 0.0, 78, 78])
lon_corners = np.array([72, 84, 84, 72]) 


poly_corners = np.zeros((len(lat_corners), 2), np.float64)
poly_corners[:,0] = lon_corners
poly_corners[:,1] = lat_corners

poly = mpatches.Polygon(poly_corners, closed=True, #ec='r', 
                        fill=True, lw=1, fc="grey",
                        alpha=0.4, 
                        #transform=ccrs.epsg(32643))
                        transform=ccrs.Geodetic(),
                        label = 'Projected bounds')
ax.add_patch(poly)

# epsg:32643 center coordinates
plt.plot(500000.00, 4649776.22, color='blue', marker='o',
         markersize=1, transform=ccrs.epsg(32643))

lat_corners2 = np.array([0.0, 0.0, 78, 78])
lon_corners2 = np.array([72, 78, 78, 72]) 

poly_corners2 = np.zeros((len(lat_corners2), 2), np.float64)
poly_corners2[:,0] = lon_corners2
poly_corners2[:,1] = lat_corners2

poly2 = mpatches.Polygon(poly_corners2, closed=True, ec='r', 
                        fill=False, lw=1, #fc="grey",
                        alpha=1, 
                        #transform=ccrs.epsg(32643))
                        transform=ccrs.Geodetic(),
                        label = 'UTM zone 43N extent')
ax.add_patch(poly2)

lat_corners3 = np.array([16, 16, 20, 20])
lon_corners3 = np.array([72, 78, 78, 72]) 

poly_corners3 = np.zeros((len(lat_corners3), 2), np.float64)
poly_corners3[:,0] = lon_corners3
poly_corners3[:,1] = lat_corners3

#Open Series Map ~ E-43 extent:https://deeppradhan.heliohost.org/gis/map-numbering/osm.htm
# unhash #ax.add_patch(poly3) and execute to see
poly3 = mpatches.Polygon(poly_corners3, closed=True, ec='b', 
                         facecolor='white', alpha=0.2, hatch='xxxx',
                         fill=False, lw=1, #fc="grey",
                         #alpha=1, 
                         #transform=ccrs.epsg(32643))
                         transform=ccrs.Geodetic(),
                         label = 'Open Series Map sheet E-43 extent')
#ax.add_patch(poly3)

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlabels = True
gl.ylabels = False
#gl.left_labels = True
gl.ylines = True
gl.ylocator = mticker.FixedLocator([])#16, 20])
gl.xlocator = mticker.FixedLocator([75])
#gl.ylocator = LatitudeLocator()
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size':15, 'color': 'black'}
gl.ylabel_style = {'weight':'bold', 'color': 'grey'}

#add legend
ax.legend(bbox_to_anchor=(1.2, 1.05), loc='upper right')
#save
plt.savefig('./img/UTMzone43N.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=-69, 
                                                  central_latitude=-30))
plt.title('SIRGAS-Chile 2002 / UTM zone 19S', fontweight="bold", pad=20)
ax.stock_img()
ax.gridlines(draw_labels=True)

# epsg:3948 extents
#lat_corners = np.array([13832782.12, 13832782.12, 6971387.77, 6971387.77])
#lon_corners = np.array([-3810056.30, 1671181.85, 1671181.85, -3810056.30]) 
lat_corners = np.array([-59.87, -59.87, -17.5, -17.5])
lon_corners = np.array([-72.0, -66.0, -66.0, -72])

poly_corners = np.zeros((len(lat_corners), 2), np.float64)
poly_corners[:,0] = lon_corners
poly_corners[:,1] = lat_corners

poly = mpatches.Polygon(poly_corners, closed=True, #ec='r', 
                        fill=True, lw=1, fc="grey",
                        alpha=0.4, 
                        #transform=ccrs.epsg(5641),
                        transform=ccrs.Geodetic(),
                        label = 'Projected bounds')

# epsg:3948 center coordinates
plt.plot(500000.00, 5718178.36, color='blue', marker='o',
         markersize=1, transform=ccrs.epsg(5361)) 
    
ax.add_patch(poly)

lat_corners2 = np.array([-59.87, -59.87, -17.5, -17.5])
lon_corners2 = np.array([-72.0, -66.0, -66.0, -72.0]) 

poly_corners2 = np.zeros((len(lat_corners2), 2), np.float64)
poly_corners2[:,0] = lon_corners2
poly_corners2[:,1] = lat_corners2

poly2 = mpatches.Polygon(poly_corners2, closed=True, ec='r', 
                        fill=False, lw=1, #fc="grey",
                        alpha=1, 
                        #transform=ccrs.epsg(2048))
                        transform=ccrs.Geodetic(),
                        label = 'SIRGAS-Chile 2002\nUTM zone 19S extent')
ax.add_patch(poly2)

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='grey', alpha=0.4, linestyle='--')
gl.xlabels = False
gl.ylabels = False
#gl.left_labels = True
gl.ylines = True
gl.ylocator = mticker.FixedLocator([])#-59, -17])
gl.xlocator = mticker.FixedLocator([-69])
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size': 15, 'color': 'black'}
gl.ylabel_style = {'color': 'grey', 'weight': 'bold'}

#add legend
ax.legend(bbox_to_anchor=(1.15, 1.09), loc='upper right')
#save
plt.savefig('./img/SIRGAS2BrazilMercator.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.NearsidePerspective(central_longitude=153.0, 
                                                 central_latitude=-30.0))
plt.title('GDA94 / MGA zone 56', fontweight="bold", pad=20)
ax.stock_img()
ax.gridlines(draw_labels=True)

# EPSG:28356 extents
lat_corners2 = np.array([-60, -60, -60, -60, -60, -8, -8, -8, -8, -8])
lon_corners2 = np.array([93, 110, 130, 150, 173, 173, 150, 130, 110, 93]) 

poly_corners2 = np.zeros((len(lat_corners2), 2), np.float64)
poly_corners2[:,0] = lon_corners2
poly_corners2[:,1] = lat_corners2

poly2 = mpatches.Polygon(poly_corners2, closed=True, #ec='r', 
                        fill=True, lw=1, fc="grey",
                        alpha=0.3, 
                        #transform=ccrs.epsg(28356))
                        transform=ccrs.Geodetic(),
                        label = 'Projected bounds')
ax.add_patch(poly2)

#lat_corners = np.array([0.0, 0.0, 534994.66, 534994.66])
#lon_corners = np.array([166021.44, 9329005.18, 9329005.18, 166021.44]) 
lat_corners = np.array([-60, -60, -8, -8])
lon_corners = np.array([150, 156, 156, 150]) 

poly_corners = np.zeros((len(lat_corners), 2), np.float64)
poly_corners[:,0] = lon_corners
poly_corners[:,1] = lat_corners

poly = mpatches.Polygon(poly_corners, closed=True, ec='r', 
                        fill=False, lw=1, #fc="grey",
                        alpha=1, 
                        #transform=ccrs.epsg(28356))
                        transform=ccrs.Geodetic(),
                        label = 'MGA zone 56 extent')
ax.add_patch(poly)

# epsg:32643 center coordinates
plt.plot(-1313219.12, 6000628.16, color='blue', marker='o',
         markersize=1, transform=ccrs.epsg(28356))

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, 
                  linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlabels = False
gl.ylabels = False
#gl.left_labels = True
gl.ylines = True
gl.ylocator = mticker.FixedLocator([])#-20, -40])#[0, -15, -30, -80])
gl.xlocator = mticker.FixedLocator([153])
#gl.ylocator = LatitudeLocator()
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size':15, 'color': 'black'}
gl.ylabel_style = {'weight':'bold', 'color': 'grey'}

#add legend
ax.legend(bbox_to_anchor=(1.1, 1.1), loc='upper right')
#save
plt.savefig('./img/MGAzone56.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))

#centre the projection
map_proj = ccrs.NearsidePerspective(central_longitude=-84, 
                                    central_latitude=59.0)

map_proj._threshold /= 100.  # the default values is bad, users need to set them manually
ax = plt.axes(projection=map_proj)

plt.title('NAD83(CSRS) / Teranet Ontario Lambert', fontweight="bold", pad=20)
ax.stock_img()
ax.gridlines(draw_labels=True)

# epsg:2048 extents
#lat_corners = np.array([-3454415.91, -3454415.91, 6848343.70, 6848343.70])
#lon_corners = np.array([1381376.16, 10828392.64, 10828392.64, 1381376.16]) 
lat_corners = np.array([40, 40, 40, 40, 40, 40, 86, 86])
lon_corners = np.array([-141, -115, -100, -84, -60, -47, -47, -141]) 

poly_corners = np.zeros((len(lat_corners), 2), np.float64)
poly_corners[:,0] = lon_corners
poly_corners[:,1] = lat_corners

poly = mpatches.Polygon(poly_corners, closed=True, #ec='r', 
                        fill=True, lw=1, fc="grey",
                        alpha=0.4, 
                        #transform=ccrs.epsg(5321))
                        transform=ccrs.Geodetic(),
                        label = 'Projected bounds')
ax.add_patch(poly)
# standard parallels
lat_corners2 = np.array([45.5, 45.5, 45.5, 45.5, 45.5, 45.5, 45.5, 45.5, 45.5, 45.5, 45.5, 
                         45.5, 55.5, 55.5, 55.5, 55.5, 55.5, 55.5, 55.5, 55.5, 55.5, 55.5, 
                         55.5, 55.5])
lon_corners2 = np.array([-141, -135, -125, -115, -105, -95, -84, -70, -60, -55, -50, -47, -47, 
                         -50, -55, -60, -70, -84, -95, -105, -115, -125, -135, -141]) 

poly_corners2 = np.zeros((len(lat_corners2), 2), np.float64)
poly_corners2[:,0] = lon_corners2
poly_corners2[:,1] = lat_corners2

poly2 = mpatches.Polygon(poly_corners2, closed=True, ec='r', 
                        fill=False, lw=1, #fc="grey",
                        alpha=1, 
                        #transform=ccrs.epsg(28356))
                        transform=ccrs.Geodetic(),
                        label = 'Ontario Lambert\nextent')
ax.add_patch(poly2)

# epsg:32643 center coordinates
plt.plot(465482.80, 7705296.35, color='blue', marker='o',
         markersize=1, transform=ccrs.epsg(5321))

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=2, color='grey', alpha=0.4, linestyle='--')
#gl.xlabels = True
#gl.ylabels = True
#gl.left_labels = True
#gl.ylines = True
gl.ylocator = mticker.FixedLocator([45.5, 55.5])
gl.xlocator = mticker.FixedLocator([-84])
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size': 15, 'color': 'black'}
gl.ylabel_style = {'color': 'grey', 'weight': 'bold'}

# data available ~ https://www.sciencebase.gov/catalog/item/5ab555c6e4b081f61ab78093
df = gpd.read_file('gpr_000b11a_e.shp')
ont = df[df['PRENAME'] == 'Ontario']
ax.add_geometries(ont.geometry, crs=ccrs.PlateCarree(), 
                  linewidth=0.5, facecolor='white', alpha=0.1, hatch='xxxx')
                  #edgecolor='gray')   
#add legend
ax.legend(bbox_to_anchor=(1.2, 1.05), loc='upper right')

#save
plt.savefig('./img/CSRSOntarioLambert.png', bbox_inches='tight')
plt.show()
